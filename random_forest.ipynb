# %% [markdown]
# # Random Forest Classifier
# ## Credit Card Fraud Detection
#
# **Objective:**
# To train and evaluate a Random Forest model for detecting fraudulent
# transactions and compare its performance with Logistic Regression.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_auc_score,
    PrecisionRecallDisplay
)

# %%
df = pd.read_csv("data/creditcard.csv")

X = df.drop(columns=["Class"])
y = df["Class"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %% [markdown]
# The dataset is split using stratification to preserve class imbalance.

# %%
rf = RandomForestClassifier(
    n_estimators=200,
    class_weight="balanced",
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200, n_jobs=-1,
#                        random_state=42)

# %% [markdown]
# Class-weighted Random Forest is used to handle severe class imbalance.

# %%
y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)[:, 1]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.96      0.76      0.85        98
#
#     accuracy                           1.00     56962
#    macro avg       0.98      0.88      0.92     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Greens")
plt.title("Confusion Matrix – Random Forest")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
roc_auc_score(y_test, y_prob)
# Out:
# 0.9571890288895525

# %%
PrecisionRecallDisplay.from_predictions(y_test, y_prob)
plt.show()

# %%
importances = pd.Series(
    rf.feature_importances_,
    index=X.columns
).sort_values(ascending=False)

importances.head(10)
# Out:
# V14    0.172755
# V4     0.115382
# V10    0.111231
# V12    0.093417
# V17    0.092719
# V3     0.064234
# V11    0.058795
# V16    0.051311
# V2     0.028824
# V7     0.025840
# dtype: float64

# %%
importances.head(10).plot(kind="bar")
plt.title("Top 10 Feature Importances")
plt.show()
